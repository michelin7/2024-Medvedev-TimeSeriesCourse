# %% [markdown]
# ## Анализ и прогнозирование временных рядов методами искусственного интеллекта

# %% [markdown]
# ### **Практическая работа 7. Востановление пропусков и прогноз значений временного ряда.**

# %% [markdown]
# #### **7.1 Аналитечкие методы востановления временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# В данном пункте практической работы вам предстоит познакомиться с базовыми, аналитическими методами восстановления временных рядов.
# Для выполнения данного пункта из каждой группы методов, представленных в ***табл. 7.1*** вам необходимо выбрать по одному методу восстановления ряда. При работе с первой группой, вам необходимо самостоятельно реализовать выбранный метод.
#
# **Табл. 7.1** - Группы аналитических методов восстановления.
# №|Название группы|Модели и методы|
# --|----|----|
# 1|Заполнение существующими значениями ряда|Средним, медианной, Hot-Deck|
# 2|Заполнение на основе близки значений|[Интерполяция](https://scikit-learn.org/stable/auto_examples/linear_model/plot_polynomial_interpolation.html),  [KNNi](https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html)|
# 3|На основе матричных разложений|[CD-Rec](#Fixme:Дат ссылку), [SVD](https://pypi.org/project/fancyimpute/)|

# %% [markdown]
# ##### 7.1.1 Загрузка и подготовка данных

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# %%
path_data = Path('datasets')/'madrid.txt'
madrid = np.loadtxt(path_data)[:,0]
print(madrid.shape)
# Out:
# (25000,)

# %%
fig, ax =  plt.subplots(figsize=(14,4),ncols=1,nrows=1)
plt.plot(madrid[:])
plt.show()

# %% [markdown]
# Самостоятельно реализуйте функцию, принимающую на вход многомерный временной ряд и возвращающий:
# 1. Все подпоследовательности временного ряда, в которых некоторые значения временного ряда были заменены nan значениями.
# 2. Индексы пропущенных значений
#
# Процент пропущенных значений должен регулироваться отдельным параметром.

# %%
pip install torch
# Out:
# Collecting torch
#   Downloading torch-2.5.0-cp310-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.10/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.10/site-packages (from torch) (2024.3.1)
# Collecting sympy==1.13.1 (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Downloading torch-2.5.0-cp310-none-macosx_11_0_arm64.whl (64.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 MB 5.6 MB/s eta 0:00:0000:0100:01
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 4.4 MB/s eta 0:00:00a 0:00:01
# WARNING: Error parsing dependencies of celery: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pytz (>dev)
#          ~^
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
# Successfully installed sympy-1.13.1 torch-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import copy
import torch
import random

def add_nan(x, percent = 0.25):
    x_nan = copy.deepcopy(x)
    nan_len = x.shape[0] * percent
    nan_counter = 0

    for i in range(x_nan.shape[0]):
        if nan_counter <= nan_len and random.randint(0, 1):
            x_nan[i] = np.nan
            nan_counter += 1

    return x_nan, np.isnan(x_nan)

# %%
madrid_with_nan, index = add_nan(madrid)
fig, ax =  plt.subplots(figsize=(14,6),ncols=1,nrows=2)
ax[0].plot(madrid[:1000])
ax[1].plot(madrid_with_nan[:1000])
plt.show()

# %%
recovery = {}

# %% [markdown]
# ##### 7.1.2 Заполнение существующими значениями ряда

# %%
madrid_mean = madrid_with_nan.copy()
madrid_mean[index] = np.nanmean(madrid_mean)
recovery['mean'] = madrid_mean

# %%
fig, ax =  plt.subplots(figsize=(14,6),ncols=1,nrows=2)
ax[0].plot(madrid[:1000])
ax[1].plot(madrid_mean[:1000])
plt.show()

# %%
madrid_median = madrid_with_nan.copy()
madrid_median[index] = np.nanmedian(madrid_median)

# %%
recovery['median'] = madrid_median

# %%
#madrid_with_nan, index = add_nan(madrid)
fig, ax =  plt.subplots(figsize=(14,6),ncols=1,nrows=2)
ax[0].plot(madrid[:1000])
ax[1].plot(madrid_median[:1000])
plt.show()

# %% [markdown]
# Самостоятельно реализуйте один метод из первой группы ***табл. 7.1*** и проведите постановление данных, сохранив результаты восстановления.

# %% [markdown]
# ##### 7.1.3 Заполнение на основе близких значений

# %% [markdown]
# Используя документацию одного из методов восстановления второй группы ***табл. 7.1*** и проведите восстановление данных, сохранив результаты восстановления.

# %%
from sklearn.impute import KNNImputer

# %%
def rolling_window(a, window, intersection=False):
    # result = torch.zeros(size=(a.shape[0],a.shape[1]))
    returns = []
    if intersection:  
        for i in range(0, a.shape[0]-window):
            returns.append(a[i:i + window])
    else:    
        for i in range(0, a.shape[0],window):
            returns.append(a[i:i + window])
    return np.stack(returns)

# %%
madrid_with_nan, index = add_nan(madrid)

madrid_slice = rolling_window(madrid_with_nan, 100)

imputer = KNNImputer(n_neighbors=10)

madrid_knn_imputer = imputer.fit_transform(madrid_slice)
madrid_knn_imputer = madrid_knn_imputer.ravel()

# %%
recovery['knn_imputer'] = madrid_knn_imputer

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)
ax.plot(madrid[:1000])
ax.plot(madrid_knn_imputer[:1000], alpha=0.6)
plt.show()

# %% [markdown]
# ##### 7.1.4 Заполнение на матричных преобразований

# %% [markdown]
# Используя документацию одного из методов восстановления третей группы ***табл. 7.1*** и проведите восстановление данных, сохранив результаты восстановления.

# %%
# !pip install fancyimpute
# Out:
# Collecting fancyimpute
#   Downloading fancyimpute-0.7.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting knnimpute>=0.1.0 (from fancyimpute)
#   Downloading knnimpute-0.1.0.tar.gz (8.3 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.24.2 in /opt/anaconda3/lib/python3.10/site-packages (from fancyimpute) (1.5.1)
# Collecting cvxpy (from fancyimpute)
#   Downloading cvxpy-1.5.3-cp310-cp310-macosx_10_9_universal2.whl.metadata (8.8 kB)
# Collecting cvxopt (from fancyimpute)
#   Downloading cvxopt-1.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (1.3 kB)
# Requirement already satisfied: pytest in /opt/anaconda3/lib/python3.10/site-packages (from fancyimpute) (7.4.4)
# Requirement already satisfied: nose in /opt/anaconda3/lib/python3.10/site-packages (from fancyimpute) (1.3.7)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.10/site-packages (from knnimpute>=0.1.0->fancyimpute) (1.16.0)
# Requirement already satisfied: numpy>=1.10 in /opt/anaconda3/lib/python3.10/site-packages (from knnimpute>=0.1.0->fancyimpute) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.24.2->fancyimpute) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.24.2->fancyimpute) (3.5.0)
# Collecting osqp>=0.6.2 (from cvxpy->fancyimpute)
#   Downloading osqp-0.6.7.post3-cp310-cp310-macosx_11_0_arm64.whl.metadata (1.9 kB)
# Collecting ecos>=2 (from cvxpy->fancyimpute)
#   Downloading ecos-2.0.14.tar.gz (142 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting clarabel>=0.5.0 (from cvxpy->fancyimpute)
#   Downloading clarabel-0.9.0-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.8 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy->fancyimpute)
#   Downloading scs-3.2.7-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: iniconfig in /opt/anaconda3/lib/python3.10/site-packages (from pytest->fancyimpute) (1.1.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.10/site-packages (from pytest->fancyimpute) (24.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/anaconda3/lib/python3.10/site-packages (from pytest->fancyimpute) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /opt/anaconda3/lib/python3.10/site-packages (from pytest->fancyimpute) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /opt/anaconda3/lib/python3.10/site-packages (from pytest->fancyimpute) (2.0.1)
# Collecting qdldl (from osqp>=0.6.2->cvxpy->fancyimpute)
#   Downloading qdldl-0.1.7.post4-cp310-cp310-macosx_11_0_arm64.whl.metadata (1.7 kB)
# Downloading cvxopt-1.3.2-cp310-cp310-macosx_11_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 4.7 MB/s eta 0:00:00a 0:00:01
# Downloading cvxpy-1.5.3-cp310-cp310-macosx_10_9_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.4 MB/s eta 0:00:00-:--:--
# Downloading clarabel-0.9.0-cp37-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.7 MB/s eta 0:00:00a 0:00:01
# Downloading osqp-0.6.7.post3-cp310-cp310-macosx_11_0_arm64.whl (237 kB)
# Downloading scs-3.2.7-cp310-cp310-macosx_11_0_arm64.whl (93 kB)
# Downloading qdldl-0.1.7.post4-cp310-cp310-macosx_11_0_arm64.whl (98 kB)
# Building wheels for collected packages: fancyimpute, knnimpute, ecos
#   Building wheel for fancyimpute (setup.py) ... done
#   Created wheel for fancyimpute: filename=fancyimpute-0.7.0-py3-none-any.whl size=29881 sha256=bd6189b6485068839e6f53a7bf2210ce1f293c54b46212e12329e110f9a395b4
#   Stored in directory: /Users/mikhailmedvedev/Library/Caches/pip/wheels/7b/0c/d3/ee82d1fbdcc0858d96434af108608d01703505d453720c84ed
#   Building wheel for knnimpute (setup.py) ... done
#   Created wheel for knnimpute: filename=knnimpute-0.1.0-py3-none-any.whl size=11331 sha256=d2ce7a92b4479d1228b459c7fcba4d7197dc7253b58a0f5549a9bd43b8b593aa
#   Stored in directory: /Users/mikhailmedvedev/Library/Caches/pip/wheels/46/06/a5/45a724630562413c374e29c08732411d496092408b3a7bf754
#   Building wheel for ecos (pyproject.toml) ... done
#   Created wheel for ecos: filename=ecos-2.0.14-cp310-cp310-macosx_11_0_arm64.whl size=72663 sha256=68986cd1baf48ceee389c35ea17b60edf06dfc4a2c5b82ebe598d769bc548e54
#   Stored in directory: /Users/mikhailmedvedev/Library/Caches/pip/wheels/e1/cf/5e/e0839639dc3777967d18c04d65e5233e81049a89259062c081
# Successfully built fancyimpute knnimpute ecos
# WARNING: Error parsing dependencies of celery: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pytz (>dev)
#          ~^
# Installing collected packages: knnimpute, cvxopt, scs, qdldl, ecos, clarabel, osqp, cvxpy, fancyimpute
# Successfully installed clarabel-0.9.0 cvxopt-1.3.2 cvxpy-1.5.3 ecos-2.0.14 fancyimpute-0.7.0 knnimpute-0.1.0 osqp-0.6.7.post3 qdldl-0.1.7.post4 scs-3.2.7

# %%
from fancyimpute import IterativeSVD

# %%
solver = IterativeSVD(rank=2)
madrid_iterative_svd = madrid_slice.copy()
madrid_iterative_svd = solver.fit_transform(madrid_iterative_svd)
madrid_iterative_svd = madrid_iterative_svd.ravel()
# Out:
# [IterativeSVD] Iter 1: observed MAE=343.978114
# [IterativeSVD] Iter 2: observed MAE=269.194835
# [IterativeSVD] Iter 3: observed MAE=259.317683
# [IterativeSVD] Iter 4: observed MAE=256.509232
# [IterativeSVD] Iter 5: observed MAE=255.619073
# [IterativeSVD] Iter 6: observed MAE=255.341047
# [IterativeSVD] Iter 7: observed MAE=255.253878
# [IterativeSVD] Iter 8: observed MAE=255.234965
# [IterativeSVD] Iter 9: observed MAE=255.233001
# [IterativeSVD] Iter 10: observed MAE=255.237468
# [IterativeSVD] Iter 11: observed MAE=255.244450

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ##### 7.1.5 Сравнение результатов восстановления.

# %% [markdown]
# Для каждой группы методов постройте методов основные метрики оценки качества постановления.
# На основе метрик отберите лучшие методы постановления метрик и выберите лучшую группу методов.
# Для лучших методов из каждой группы постройте графики сравнения реальных и восстановленных данных. Объясните результаты и сделайте вывод.

# %% [markdown]
# *Вывод*:

# %% [markdown]
# #### **7.2 Нейросетевые методы востановления временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# В данном пункте практической работы вам предстоит познакомиться с некоторыми нейросетевыми методами восстановления временных рядов.
# Для выполнения данного пункта вам предстоит самостоятельно реализовать структуру нейросетевой, модели основанной на GRU нейронах и сравнить ее с другими нейросетевыми методами восстановления При сравнении с 3 группой из **табл.7. 2** вам необходимо выбрать **один** метод восстановления. Основные блоки обработки данных будут реализованы с использованием Pytorch. Вам не запрещается использовать для реализации Keras.
#
# **табл. 7.2** - Нейросетевые методы восстановления.
# №|Название группы|Модели и методы|
# --|-------------|----|
# 1|Линейные нейроны|[Pytorch](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)|
#  2eкрркуретные нейронны|[Pytorch](https://pytorch.org/docs/stable/generated/torch.nn.GRU.html)|
# 3|Сложные структуры|[SAITS, BRITS, M-RNN](https://github.com/WenjieDu/PyPOTS)|

# %%
recovery_nn = {}

# %% [markdown]
# ##### 7.2.1 Загрузка и подготовка данных

# %%
path_data = Path('datasets')/'madrid.txt'
madrid = np.loadtxt(path_data)[:,:]
print(madrid.shape)
# Out:
# (25000, 10)

# %%
madrid_with_nan, index = add_nan(madrid, 0.25)

# %%
madrid_with_nan.shape
# Out:
# (25000, 10)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
madrid_normal_with_nan = scaler.fit_transform(madrid_with_nan)
rolling_madrid = rolling_window(madrid_normal_with_nan, 100, True)
train, test = train_test_split(rolling_madrid,shuffle=False, test_size=0.33)

# %% [markdown]
# ##### 7.2.2 Базовая модель восстановления данных, построенная на нескольких слоях линейных нейронов.

# %% [markdown]
# Вам необходимо будет самостоятельно реализовать:
# 1. инициализацию nan значений какими либо другими значениями.
# 2. замер времени полного обучения и тестирования модели.

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader

# %%
class LinearModel(nn.Module):
    def __init__(self, size_subsequent: int,dim = 1, nums_layers = 3, size_layers = 250):
        super().__init__()  
        
        self.size_subsequent = size_subsequent
        self.nums_layers = nums_layers*dim
        self.dim = dim
        self.size_layers = size_layers
        
        self.start_layers = nn.Sequential(nn.Flatten(),
                                          nn.Linear(size_subsequent*dim, self.size_layers),
                                          nn.LeakyReLU())
        self.model = nn.ModuleList([
                                        (nn.Sequential(
                                                nn.Linear(self.size_layers, self.size_layers), nn.LeakyReLU()
                                            ) 
                                        )
                                    for x in torch.arange(nums_layers)])
        self.model = nn.Sequential(*self.model)
        
        self.output = nn.Sequential(nn.Linear(self.size_layers,size_subsequent*dim),nn.Tanh())
        
    def forward(self, x):
        x = self.start_layers(x)
        
        x=self.model(x)
        x=self.output(x)
        return x.reshape(x.shape[0],self.size_subsequent,self.dim)

# %%
model = LinearModel(size_subsequent=train.shape[1],dim=train.shape[2])
optimizer = torch.optim.Adam(model.parameters(),lr=1.0e-3)
loss_func = nn.MSELoss()
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
batch_size = 64
percent = 0.25

train_loader = DataLoader(train,batch_size=batch_size,shuffle=True)
valid_loader = DataLoader(test,batch_size=batch_size,shuffle=True)

print(train.shape,test.shape)
epochs = 100
# Out:
# (16683, 100, 10) (8217, 100, 10)

# %%
model
# Out:
# LinearModel(
#   (start_layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=1000, out_features=250, bias=True)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (model): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=250, out_features=250, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=250, out_features=250, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=250, out_features=250, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (output): Sequential(
#     (0): Linear(in_features=250, out_features=1000, bias=True)
#     (1): Tanh()
#   )
# )

# %%
import time
times_model = {}

# %%
model=model.to(device)
train_history = []
valid_history = []

start = time.time()
for epoch in np.arange(epochs):
    train_loss =0
    valid_loss =0

    for i, x in enumerate(train_loader):
        if x.shape[0] == batch_size:
            optimizer.zero_grad()
            x = x.to(device).to(torch.float32)
            test_index = np.isnan(x.cpu().numpy())
            X = x.clone()
            X, nan = add_nan(X,percent)
            X[torch.isnan(X)] = 0.0  # Инициализация пропущенных значений нулями
            recovery = model(X)
            loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
            train_loss += loss.detach().cpu().item()
            loss.backward()
            optimizer.step()
    train_loss/=(i+1)
    print('valid')
    with torch.no_grad():
        for i, x in enumerate(valid_loader):
            if x.shape[0] == batch_size:
                x = x.to(device).to(torch.float32)
                test_index = np.isnan(x.cpu().numpy())
                X = x.clone()
                X, nan = add_nan(X,percent)
                X[torch.isnan(X)]=0.0
                recovery = model(X)
                loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
                valid_loss += loss.detach().cpu().item()
    valid_loss/=(i+1)
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'epoch:{epoch+1} train:{train_loss}, valid:{valid_loss}')
end = time.time()
# Out:
# /var/folders/d_/m9h_bd6161x8tltvkzyg86740000gn/T/ipykernel_3837/262026474.py:19: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:28.)
#   loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
# /opt/anaconda3/lib/python3.10/site-packages/torch/autograd/graph.py:825: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:28.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# valid
# epoch:1 train:0.03461162277793519, valid:0.03441709623664849
# /var/folders/d_/m9h_bd6161x8tltvkzyg86740000gn/T/ipykernel_3837/262026474.py:34: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:28.)
#   loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
# valid
# epoch:2 train:0.03223414005447622, valid:0.033139917681845585
# valid
# epoch:3 train:0.03267117519773743, valid:0.03355105722308621
# valid
# epoch:4 train:0.03271388092659899, valid:0.03312648070413013
# valid
# epoch:5 train:0.03282708461285779, valid:0.03512584328535916
# valid
# epoch:6 train:0.0323713321124571, valid:0.03367566165709218
# valid
# epoch:7 train:0.032873578954816324, valid:0.03393802549256835
# valid
# epoch:8 train:0.032568314644397446, valid:0.03407460868416368
# valid
# epoch:9 train:0.03271517271026113, valid:0.03357830848689227
# valid
# epoch:10 train:0.0322663783670271, valid:0.035059046361219974
# valid
# epoch:11 train:0.03258307712059825, valid:0.033947309089261433
# valid
# epoch:12 train:0.032512098522250225, valid:0.03438278094165085
# valid
# epoch:13 train:0.032590651584939026, valid:0.0335477076095435
# valid
# epoch:14 train:0.03242322304410953, valid:0.0336977125744718
# valid
# epoch:15 train:0.0325485167318377, valid:0.03429725018236064
# valid
# epoch:16 train:0.03240760218823093, valid:0.034006164170974906
# valid
# epoch:17 train:0.032400420363778354, valid:0.03376845237185327
# valid
# epoch:18 train:0.032426868033706, valid:0.0340568239605704
# valid
# epoch:19 train:0.03268717766036476, valid:0.03443610936749813
# valid
# epoch:20 train:0.032399129143905366, valid:0.03386119120689326
# valid
# epoch:21 train:0.03245287016747783, valid:0.03410806606502034
# valid
# epoch:22 train:0.03255313494281979, valid:0.03303867239187392
# valid
# epoch:23 train:0.032706857070155526, valid:0.03324838589097178
# valid
# epoch:24 train:0.032600465969278895, valid:0.03363536953810574
# valid
# epoch:25 train:0.03270098594127944, valid:0.03468995760808619
# valid
# epoch:26 train:0.03248088175994683, valid:0.033396860021491385
# valid
# epoch:27 train:0.032449070349963686, valid:0.03346193565936514
# valid
# epoch:28 train:0.03266053810944046, valid:0.03416631304362948
# valid
# epoch:29 train:0.03257026659660184, valid:0.034403570703873336
# valid
# epoch:30 train:0.0324122062545284, valid:0.0339314098534889
# valid
# epoch:31 train:0.032460317921992464, valid:0.03422637168289155
# valid
# epoch:32 train:0.0325858104131916, valid:0.03457795069083687
# valid
# epoch:33 train:0.03242907778741756, valid:0.033931381394003715
# valid
# epoch:34 train:0.03251326657917308, valid:0.034556999918102294
# valid
# epoch:35 train:0.032342626581189735, valid:0.034468362382216046
# valid
# epoch:36 train:0.03248940913499087, valid:0.033929971905872804
# valid
# epoch:37 train:0.03263331169683586, valid:0.03316238978805468
# valid
# epoch:38 train:0.03251797701606805, valid:0.034287091012495434
# valid
# epoch:39 train:0.0326134467647336, valid:0.034309904704722324
# valid
# epoch:40 train:0.032224673941959825, valid:0.033922203116176664
# valid
# epoch:41 train:0.03250948119894298, valid:0.03427901661904283
# valid
# epoch:42 train:0.03252219737746478, valid:0.033449655730825985
# valid
# epoch:43 train:0.032779807310508585, valid:0.03419249117836472
# valid
# epoch:44 train:0.03245287120228069, valid:0.034035019778697065
# valid
# epoch:45 train:0.03246910779440768, valid:0.03405189309124799
# valid
# epoch:46 train:0.03287480271267937, valid:0.03370158719404261
# valid
# epoch:47 train:0.032615540078145336, valid:0.03319936372744021
# valid
# epoch:48 train:0.03220769651662344, valid:0.03369426565576893
# valid
# epoch:49 train:0.03248678545299846, valid:0.03359134176154007
# valid
# epoch:50 train:0.03236026208405294, valid:0.03391224820195705
# valid
# epoch:51 train:0.032369697238122365, valid:0.03381633754213189
# valid
# epoch:52 train:0.032558178750377045, valid:0.034386381766823834
# valid
# epoch:53 train:0.03251113517074292, valid:0.03361714723729348
# valid
# epoch:54 train:0.03251264801684239, valid:0.03400121385217175
# valid
# epoch:55 train:0.03219300871750633, valid:0.0337137698174216
# valid
# epoch:56 train:0.032581736529923945, valid:0.0337777907649676
# valid
# epoch:57 train:0.03261099016415205, valid:0.03371689133634863
# valid
# epoch:58 train:0.032591056992153554, valid:0.033548777215471566
# valid
# epoch:59 train:0.03245835672079147, valid:0.03353138260774372
# valid
# epoch:60 train:0.032461093560260834, valid:0.03426143115516319
# valid
# epoch:61 train:0.03258548609883849, valid:0.033653052552610405
# valid
# epoch:62 train:0.03250834494258252, valid:0.03473793472661529
# valid
# epoch:63 train:0.032227950063587606, valid:0.03386173811705075
# valid
# epoch:64 train:0.03264211617067628, valid:0.033388124475645466
# valid
# epoch:65 train:0.032676490287785326, valid:0.034204710765864496
# valid
# epoch:66 train:0.032331027854162614, valid:0.033871085462413096
# valid
# epoch:67 train:0.03253330774890737, valid:0.03322023959007374
# valid
# epoch:68 train:0.03272093364333741, valid:0.03391608341719753
# valid
# epoch:69 train:0.03237383091158565, valid:0.03348233908876892
# valid
# epoch:70 train:0.03236128968611302, valid:0.03372433520275955
# valid
# epoch:71 train:0.03243941194252949, valid:0.03479308142622774
# valid
# epoch:72 train:0.032406755819402895, valid:0.03398802112643571
# valid
# epoch:73 train:0.03234538979742719, valid:0.03329418277613414
# valid
# epoch:74 train:0.03220585952031201, valid:0.03444598102581131
# valid
# epoch:75 train:0.032440854529083005, valid:0.033307995170701384
# valid
# epoch:76 train:0.03267777609813716, valid:0.03384336692013944
# valid
# epoch:77 train:0.0325503922085424, valid:0.03359478804492211
# valid
# epoch:78 train:0.03218310536866672, valid:0.033549685305518696
# valid
# epoch:79 train:0.03248508781251779, valid:0.03397559397673422
# valid
# epoch:80 train:0.032334572931758745, valid:0.03402181831729967
# valid
# epoch:81 train:0.03251752395082936, valid:0.03307300091309603
# valid
# epoch:82 train:0.03240916445508771, valid:0.03421555008999137
# valid
# epoch:83 train:0.03238808806143501, valid:0.033475086872660834
# valid
# epoch:84 train:0.03274452215296098, valid:0.033413092266450554
# valid
# epoch:85 train:0.03268673828307011, valid:0.033297822023778
# valid
# epoch:86 train:0.032363018977288084, valid:0.03351034447839556
# valid
# epoch:87 train:0.03226605104104084, valid:0.03395721046326235
# valid
# epoch:88 train:0.03218196517291882, valid:0.033565101177655446
# valid
# epoch:89 train:0.03208609713933706, valid:0.033828730009091916
# valid
# epoch:90 train:0.0326100648505706, valid:0.03429929330194181
# valid
# epoch:91 train:0.032737213775686835, valid:0.03357267519820106
# valid
# epoch:92 train:0.03238750306239987, valid:0.03416876266746558
# valid
# epoch:93 train:0.03260602353861505, valid:0.03410547830222189
# valid
# epoch:94 train:0.032324207803926704, valid:0.0341512120451576
# valid
# epoch:95 train:0.03242243839235141, valid:0.03374337152281935
# valid
# epoch:96 train:0.03233689347360554, valid:0.034226712879053385
# valid
# epoch:97 train:0.03221290713440184, valid:0.03371097340948822
# valid
# epoch:98 train:0.032685909320339844, valid:0.03400690774180631
# valid
# epoch:99 train:0.03250134408730885, valid:0.03390771453810293
# valid
# epoch:100 train:0.03269609534163813, valid:0.03381176386750484

# %%
times_model['linear']=end-start

# %%
plt.plot(train_history,label='train')
plt.plot(valid_history,label='valid')
plt.legend()
plt.show()

# %%
test_rolling_madrid = rolling_window(madrid_normal_with_nan, 100, False)
#test = []
with torch.no_grad():
    for idx, batch in enumerate(test_rolling_madrid):
        batch = torch.Tensor(batch).to(device)
        nan = torch.isnan(batch)
        batch[nan]=0.0
        rec = model(batch[None,:])[0].cpu().numpy()
        nan = nan.cpu().numpy()
        test_rolling_madrid[idx][nan]=rec[nan]

# %%
test_madrid_normal = np.vstack(test_rolling_madrid)
test_linear = scaler.inverse_transform(test_madrid_normal)

# %%
recovery_nn = {}

# %%
recovery_nn['linear'] = test_linear

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_linear[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_linear[index].reshape(1,-1)))
# Out:
# 6040203.299153216

# %% [markdown]
# ##### 7.2.3 Реккурентная модель востановлениях данных

# %%
class EncoderGRU(nn.Module):
    def __init__(self, size_subsequent: int, dim = 1, latten_size = 100, hidden_size=100):
        super().__init__()
        self.size_subsequent=size_subsequent
        self.dim = dim
        self.hidden_size = hidden_size
        self.gru = nn.GRU(input_size=dim,
                          hidden_size=self.hidden_size)
        
        self.latten = nn.Linear(hidden_size*size_subsequent,latten_size)
        self.leaky = nn.LeakyReLU()
        self.fl = nn.Flatten()
    def forward(self, x):
        x, _ = self.gru(x)
        x = self.leaky(x)
        #print(x.shape)
        x = self.fl(x)
        x = self.latten(x)
        return self.leaky(x)

# %%
class DecoderGRU(nn.Module):
    def __init__(self, size_subsequent: int, dim = 1, latten_size = 100, hidden_size=100):
        super().__init__()
        self.size_subsequent=size_subsequent
        self.dim = dim
        self.hidden_size = hidden_size
        self.latten_size=latten_size
        self.gru = nn.GRU(input_size=self.hidden_size,
                          hidden_size=dim)
        self.latten = nn.Linear(latten_size,hidden_size*size_subsequent)
        self.leaky = nn.LeakyReLU()
    
    def forward(self, x):
        x = self.latten(x)
        x = x.view(-1, self.size_subsequent, self.latten_size)
        x = self.leaky(x)
        x, _ = self.gru(x)
        return self.leaky(x)

# %%
class TimeAE(nn.Module):
    def __init__(self, size_subsequent: int, dim = 1, latten_size = 100, hidden_size=100):
        super().__init__()
        self.encoder = EncoderGRU(size_subsequent=size_subsequent,
                                 dim=dim,
                                 latten_size=latten_size,
                                 hidden_size=hidden_size) 
        self.decoder = DecoderGRU(size_subsequent=size_subsequent,
                                 dim=dim,
                                 latten_size=latten_size,
                                 hidden_size=hidden_size) 
    def forward(self, x):
        x=self.encoder(x)
        x = self.decoder(x)
        return x

# %%
model = TimeAE(size_subsequent=train.shape[1],dim=train.shape[2])
optimizer = torch.optim.Adam(model.parameters(),lr=1.0e-3)
loss_func = nn.MSELoss()
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
batch_size = 64
percent = 0.25

train_loader = DataLoader(train,batch_size=batch_size,shuffle=True)
valid_loader = DataLoader(test,batch_size=batch_size,shuffle=True)


epochs = 100

# %%
model
# Out:
# TimeAE(
#   (encoder): EncoderGRU(
#     (gru): GRU(10, 100)
#     (latten): Linear(in_features=10000, out_features=100, bias=True)
#     (leaky): LeakyReLU(negative_slope=0.01)
#     (fl): Flatten(start_dim=1, end_dim=-1)
#   )
#   (decoder): DecoderGRU(
#     (gru): GRU(100, 10)
#     (latten): Linear(in_features=100, out_features=10000, bias=True)
#     (leaky): LeakyReLU(negative_slope=0.01)
#   )
# )

# %%
model=model.to(device)
train_history = []
valid_history = []
start = time.time()
for epoch in np.arange(epochs):
    train_loss =0
    valid_loss =0

    for i, x in enumerate(train_loader):
        if x.shape[0]==batch_size:
            optimizer.zero_grad()
            x = x.to(device).to(torch.float32)
            test_index = np.isnan(x.cpu().numpy())
            X = x.clone()
            X, nan = add_nan(X,percent)
            X[torch.isnan(X)] = 0.0  # Инициализация пропущенных значений нулями
            
            recovery = model(X)
            loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
            train_loss += loss.detach().cpu().item()
            loss.backward()
            optimizer.step()
    train_loss/=(i+1)
    with torch.no_grad():
        for i, x in enumerate(valid_loader):
            if x.shape[0]==batch_size:
                x = x.to(device).to(torch.float32)
                test_index = np.isnan(x.cpu().numpy())
                X = x.clone()
                X, nan = add_nan(X,percent)
                X[torch.isnan(X)] = 0.0  # Инициализация пропущенных значений нулями
                
                recovery = model(X)
                loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
                valid_loss += loss.detach().cpu().item()
    valid_loss/=(i+1)
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'epoch:{epoch+1} train:{train_loss}, valid:{valid_loss}')
end = time.time()
# Out:
# /var/folders/d_/m9h_bd6161x8tltvkzyg86740000gn/T/ipykernel_3837/3140299745.py:19: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:28.)
#   loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
# /var/folders/d_/m9h_bd6161x8tltvkzyg86740000gn/T/ipykernel_3837/3140299745.py:34: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/IndexingUtils.h:28.)
#   loss = loss_func(recovery[(nan)&(~test_index)],x[(nan)&(~test_index)])
# epoch:1 train:0.03272986162268339, valid:0.03429054647915123
# epoch:2 train:0.03263004785011098, valid:0.03361651559844035
# epoch:3 train:0.03248748406625114, valid:0.0332513597844414
# epoch:4 train:0.03272180947193241, valid:0.03335452313686526
# epoch:5 train:0.03209685713366759, valid:0.03412823646163293
# epoch:6 train:0.03255539484521895, valid:0.03519579633897127
# epoch:7 train:0.03265315676785977, valid:0.03425735430142214
# epoch:8 train:0.03245924732922594, valid:0.03332607157874939
# epoch:9 train:0.03233677541330399, valid:0.032967715675747675
# epoch:10 train:0.03242675534724276, valid:0.033785314479655076
# epoch:11 train:0.03250351184943398, valid:0.03455614341899406
# epoch:12 train:0.03240634665835178, valid:0.03331616883303306
# epoch:13 train:0.032120861020296015, valid:0.0338715639456298
# epoch:14 train:0.032233770487123524, valid:0.03391163469862568
# epoch:15 train:0.03284006353853078, valid:0.03394696877388529
# epoch:16 train:0.032447543352043036, valid:0.03383402561032495
# epoch:17 train:0.03258464615292476, valid:0.03435588414354842
# epoch:18 train:0.0327127534268117, valid:0.03322419477987659
# epoch:19 train:0.03227920923738872, valid:0.03359320585060027
# epoch:20 train:0.03248154806594054, valid:0.033551831679173215
# epoch:21 train:0.03253093580947297, valid:0.034158122819638995
# epoch:22 train:0.032292287304312335, valid:0.03328749440725921
# epoch:23 train:0.03256769413378275, valid:0.03441812219314797
# epoch:24 train:0.032386505012882164, valid:0.0333919690041117
# epoch:25 train:0.03252506622923288, valid:0.03392016321651695
# epoch:26 train:0.03231074047984976, valid:0.034190506508299544
# epoch:27 train:0.032135397624010326, valid:0.0350862681981205
# epoch:28 train:0.03227500619645091, valid:0.03359828542831332
# epoch:29 train:0.03263861643171859, valid:0.03326398371032966
# epoch:30 train:0.03275210344700064, valid:0.03417415041909661
# epoch:31 train:0.03243698210409089, valid:0.033851074083715446
# epoch:32 train:0.03241565790013107, valid:0.03357956868906816
# epoch:33 train:0.03248141923655267, valid:0.03326219248101693
# epoch:34 train:0.03211399850745996, valid:0.033234038989442265
# epoch:35 train:0.03238690011488752, valid:0.0345653944410557
# epoch:36 train:0.03251742328948901, valid:0.03365829579763172
# epoch:37 train:0.03274181378127514, valid:0.034011659118556234
# epoch:38 train:0.03265335568551588, valid:0.034723864796087724
# epoch:39 train:0.0324723565330108, valid:0.03351029558757017
# epoch:40 train:0.032248448830283466, valid:0.033507170242279075
# epoch:41 train:0.032550406738601885, valid:0.03376385445396105
# epoch:42 train:0.032139866752014766, valid:0.0334091322973024
# epoch:43 train:0.032290717608284676, valid:0.0333088240622319
# epoch:44 train:0.03207064995192477, valid:0.03440568181722201
# epoch:45 train:0.03257944699648011, valid:0.03389173182983731
# epoch:46 train:0.03262491646968542, valid:0.03332146225396053
# epoch:47 train:0.032376374300012646, valid:0.03371059111962023
# epoch:48 train:0.03212377478250827, valid:0.03455060746434123
# epoch:49 train:0.032532340764885204, valid:0.03402940373030282
# epoch:50 train:0.032569276968238456, valid:0.033696182981826535
# epoch:51 train:0.03257148059163514, valid:0.033466570599134576
# epoch:52 train:0.03245294020579007, valid:0.03334393880741541
# epoch:53 train:0.032274972568926225, valid:0.03440517793561137
# epoch:54 train:0.03208246526675891, valid:0.03411709134604118
# epoch:55 train:0.03270846937865133, valid:0.03405690018463042
# epoch:56 train:0.03236549736582228, valid:0.033593928138183994
# epoch:57 train:0.03244896163857074, valid:0.033751600342550016
# epoch:58 train:0.03243986480794419, valid:0.03352520802570868
# epoch:59 train:0.032466021912365126, valid:0.034332772254828337
# epoch:60 train:0.03219501546430634, valid:0.0336524592640326
# epoch:61 train:0.032135753217956115, valid:0.03368574743296287
# epoch:62 train:0.03257378324923387, valid:0.033393540138075516
# epoch:63 train:0.03247372427833948, valid:0.03345845903941365
# epoch:64 train:0.032340175204578485, valid:0.033331554325283036
# epoch:65 train:0.03240051444519982, valid:0.034329062515451
# epoch:66 train:0.03251535197812707, valid:0.033476311467992244
# epoch:67 train:0.032210669055638186, valid:0.03397056838685228
# epoch:68 train:0.03207091618885939, valid:0.03396516950266768
# epoch:69 train:0.03250097959405846, valid:0.033886767707245295
# epoch:70 train:0.03240083910210836, valid:0.03369742783522883
# epoch:71 train:0.032015659114866875, valid:0.0341006812112507
# epoch:72 train:0.03257063716307454, valid:0.03419991159566151
# epoch:73 train:0.032751727014266215, valid:0.03420678456855375
# epoch:74 train:0.03210208682036491, valid:0.03374679255219855
# epoch:75 train:0.0328180141161799, valid:0.033536915790087496
# epoch:76 train:0.032467843358087355, valid:0.034064748519381814
# epoch:77 train:0.03256203840804283, valid:0.03336780435990456
# epoch:78 train:0.03269096843584287, valid:0.03379060304904169
# epoch:79 train:0.03226570539547566, valid:0.03356926631211311
# epoch:80 train:0.03261563986882396, valid:0.03404928954650265
# epoch:81 train:0.032092723196151154, valid:0.03374255012518676
# epoch:82 train:0.032316945935688714, valid:0.034135284913025164
# epoch:83 train:0.03274384691911639, valid:0.03349337279219036
# epoch:84 train:0.032442013137185255, valid:0.03354532216754995
# epoch:85 train:0.03245414286081133, valid:0.03350016259581082
# epoch:86 train:0.032248361393010024, valid:0.034202760056585305
# epoch:87 train:0.03222435467316273, valid:0.03333559799795003
# epoch:88 train:0.03260950338081153, valid:0.033028542475644934
# epoch:89 train:0.03228628756014552, valid:0.033697857658645906
# epoch:90 train:0.03234864199013089, valid:0.03425923951489981
# epoch:91 train:0.03230403752647826, valid:0.03376910168417664
# epoch:92 train:0.032478774573040194, valid:0.033761632058394046
# epoch:93 train:0.03250445815880865, valid:0.034280566686345625
# epoch:94 train:0.03225235209953739, valid:0.03381333582449791
# epoch:95 train:0.032326784413093806, valid:0.034072579353932264
# epoch:96 train:0.032272878641769344, valid:0.03388103078906388
# epoch:97 train:0.03242136036327744, valid:0.0337759129587532
# epoch:98 train:0.03245518795460805, valid:0.03442306230350058
# epoch:99 train:0.03252086178952707, valid:0.03396794130635816
# epoch:100 train:0.032571503992452934, valid:0.03338991722106471

# %%
plt.plot(train_history,label='train')
plt.plot(valid_history,label='valid')
plt.legend()
plt.show()

# %%
times_model['ae']=end-start

# %%
test_rolling_madrid = rolling_window(madrid_normal_with_nan, 100, False)
with torch.no_grad():
    for idx, batch in enumerate(test_rolling_madrid):
        batch = torch.Tensor(batch).to(device)
        nan = torch.isnan(batch)
        batch[nan]=0.0
        
        rec = model(batch[None,:])[0].cpu().numpy()
        nan = nan.cpu().numpy()
        test_rolling_madrid[idx][nan]=rec[nan]

# %%
test_madrid_normal = np.vstack(test_rolling_madrid)
test_ae = scaler.inverse_transform(test_madrid_normal)

# %%
recovery_nn['test_ae'] = test_ae

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_ae[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_ae[index].reshape(1,-1)))
# Out:
# 151065.3362719804

# %% [markdown]
# ##### 7.2.4 Сложные модели нейросетевого восстановления данных

# %% [markdown]
# Вам необходимо выбрать одну модель из 3 группы таблицы 7.2 и используя документацию произвести восстановления того же ряда. Произведите замер времени.

# %%
# !pip install pypots==0.0.9
# Out:
# Collecting pypots==0.0.9
#   Downloading pypots-0.0.9-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.10/site-packages (from pypots==0.0.9) (3.8.4)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.10/site-packages (from pypots==0.0.9) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.10/site-packages (from pypots==0.0.9) (1.5.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.10/site-packages (from pypots==0.0.9) (1.13.1)
# Requirement already satisfied: torch>=1.10 in /opt/anaconda3/lib/python3.10/site-packages (from pypots==0.0.9) (2.5.0)
# Collecting tensorboard (from pypots==0.0.9)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.10/site-packages (from pypots==0.0.9) (2.2.2)
# Collecting pycorruptor (from pypots==0.0.9)
#   Downloading pycorruptor-0.0.4-py3-none-any.whl.metadata (2.0 kB)
# Collecting tsdb (from pypots==0.0.9)
#   Downloading tsdb-0.6.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pypots==0.0.9) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pypots==0.0.9) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pypots==0.0.9) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pypots==0.0.9) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pypots==0.0.9) (2024.3.1)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.10/site-packages (from torch>=1.10->pypots==0.0.9) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.10->pypots==0.0.9) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->pypots==0.0.9) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->pypots==0.0.9) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->pypots==0.0.9) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->pypots==0.0.9) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->pypots==0.0.9) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->pypots==0.0.9) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->pypots==0.0.9) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.10/site-packages (from matplotlib->pypots==0.0.9) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.10/site-packages (from pandas->pypots==0.0.9) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.10/site-packages (from pandas->pypots==0.0.9) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.10/site-packages (from scikit-learn->pypots==0.0.9) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.10/site-packages (from scikit-learn->pypots==0.0.9) (3.5.0)
# Collecting absl-py>=0.4 (from tensorboard->pypots==0.0.9)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/anaconda3/lib/python3.10/site-packages (from tensorboard->pypots==0.0.9) (1.48.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.10/site-packages (from tensorboard->pypots==0.0.9) (3.4.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/anaconda3/lib/python3.10/site-packages (from tensorboard->pypots==0.0.9) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/anaconda3/lib/python3.10/site-packages (from tensorboard->pypots==0.0.9) (72.1.0)
# Requirement already satisfied: six>1.9 in /opt/anaconda3/lib/python3.10/site-packages (from tensorboard->pypots==0.0.9) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->pypots==0.0.9)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.10/site-packages (from tensorboard->pypots==0.0.9) (3.0.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.10/site-packages (from tsdb->pypots==0.0.9) (4.66.4)
# Requirement already satisfied: pyarrow in /opt/anaconda3/lib/python3.10/site-packages (from tsdb->pypots==0.0.9) (14.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.10/site-packages (from tsdb->pypots==0.0.9) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->pypots==0.0.9) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.10/site-packages (from requests->tsdb->pypots==0.0.9) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.10/site-packages (from requests->tsdb->pypots==0.0.9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.10/site-packages (from requests->tsdb->pypots==0.0.9) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.10/site-packages (from requests->tsdb->pypots==0.0.9) (2024.8.30)
# Downloading pypots-0.0.9-py3-none-any.whl (81 kB)
# Downloading pycorruptor-0.0.4-py3-none-any.whl (17 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 6.8 MB/s eta 0:00:00a 0:00:01
# Downloading tsdb-0.6.2-py3-none-any.whl (32 kB)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# WARNING: Error parsing dependencies of celery: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pytz (>dev)
#          ~^
# Installing collected packages: tensorboard-data-server, absl-py, tensorboard, tsdb, pycorruptor, pypots
# Successfully installed absl-py-2.1.0 pycorruptor-0.0.4 pypots-0.0.9 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tsdb-0.6.2

# %%
from pypots.imputation import SAITS

# %%
model= SAITS(n_features=madrid.shape[1],
             n_steps=100,
             device=device,
             d_k=64,
             d_v=64,
             d_model=128,
             d_inner=128,
             n_head=4,
             n_layers=2,
             dropout=0.05,
             epochs=2)
# Out:
# Model initialized successfully. Number of the trainable parameters: 667608

# %%
start = time.time()
model.fit(train,test)
end = time.time()
times_model['saits']=end-start
# Out:
# epoch 0: training loss 0.1746, validating loss 0.0491
# epoch 1: training loss 0.1095, validating loss 0.0387
# Finished training.

# %%
test_rolling_madrid = rolling_window(madrid_normal_with_nan, 100, False)
test_rolling_madrid = model.impute(test_rolling_madrid)

# %%
test_madrid_normal = np.vstack(test_rolling_madrid)
test_saits = scaler.inverse_transform(test_madrid_normal)

# %%
recovery_nn['saits'] = test_saits

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
plt.plot(test_saits[:1000,0],alpha=0.6)
print(mean_squared_error(madrid[index].reshape(1,-1),test_saits[index].reshape(1,-1)))
# Out:
# 118883.19243088014

# %% [markdown]
# ##### 7.2.5 Сравнения результатов.
# Также, как и в пункте 7.1.5 постройте графики сравнения моделей. Дополнительно постройте графики сравнения времени. Сделайте выводы

# %%
fig, ax =  plt.subplots(figsize=(14,3),ncols=1,nrows=1)

plt.plot(madrid[:1000,0])
#plt.plot(test_linear[:1000,0],alpha=0.6)
plt.plot(test_ae[:1000,0],alpha=0.6)
plt.plot(test_saits[:1000,0],alpha=0.6)

# %%
times_model['linear']
# Out:
# 56.8533890247345

# %%
labels = list(times_model.keys())
times = list(times_model.values())

plt.figure(figsize=(10, 6))
plt.bar(labels, times, color='skyblue')
plt.xlabel('Функции')
plt.ylabel('Время выполнения (секунды)')
plt.title('Сравнение времени выполнения функций')
plt.grid(axis='y')

plt.show()

# %% [markdown]
# #### **7.3 Прогноз временного ряда**

# %% [markdown]
# ##### *Краткое описание*

# %% [markdown]
# Используя модель и [ARIMA](реализация) произвидите прогноз ряда на следующие колличество точек: 1, 5, 10.
# Сравните результаты. Постройте графики прогноза и точности прогноза.
