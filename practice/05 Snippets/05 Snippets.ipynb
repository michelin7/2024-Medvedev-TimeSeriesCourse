# %% [markdown]
# # Анализ и прогнозирование временных рядов методами искусственного интеллекта
#
# ## **Практическая работа 5. Поиск типичных подпоследовательностей временного ряда.**

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Импорт библиотек и модулей

# %%
import numpy as np
import matplotlib.pyplot as plt
from modules.snippets import *
from scipy import signal
from stumpy import snippets

# %% [markdown]
# ### **Задача 1. Поиск сниппетов одномерного временного ряда**
#
# В первой задаче необходимо выполнить поиск сниппетов одномерного временного ряда. Расмотрите приведенный ниже пример использования алгоритма SnipperFinder и визуализации полученных результатов для искуственного врменного ряда.

# %%
#Создание искусственного временного ряда
t = np.linspace(np.pi, 6 * 2 * np.pi, 3000)
ts = np.concatenate([np.sin(t), signal.sawtooth(t)])
plt.plot(ts)

# %%
#Поиск сниппетов
snp = snippets(ts, 600, 2, percentage=0.5)

# %%
#Визуализация результатов
plot_snippets(ts, snp)
# Out:
# 600
# <Axes: >

# %% [markdown]
# Далее вам предстоит самостоятельно выполнить поиск top-$k$ типичных подпоследовательностей временного ряда (сниппетов) с помощью алгоритма SnippetFinder на наборе данных PAMAP. Описание набора данных находится в [README-файле](datasets/PAMAP/readme.md).
#
# Выполните считывание временного ряда **показаний гироскопа на оси «Y» (угол тангажа) на временном интервале от 1790 сек. до 1930 сек.** (используя колонку с временными метками) из файла *PAMAP.txt*, который располагается в директории *./datasets/PAMAP*. Затем выполните поиск сниппетов с помощью функции `snippets()` из библиотеки stumpy. Затем визуализируйте полученные результаты, используя функцию `plot_snippets()` из модуля snippets.py.

# %%
import pandas as pd

# %%
df = pd.read_csv(r'datasets/PAMAP/PAMAP.txt', sep=' ', header=None).T
df
# Out:
#              0    1     2        3         4        5         6         7   \
# 0        505.71  2.0   NaN  35.0625  0.497271  9.08249 -1.875540  0.319610
# 1        505.72  2.0   NaN  35.0625  0.693164  8.93258 -1.677900  0.379878
# 2        505.73  2.0  79.0  35.0625  0.929013  9.04638 -1.441670  0.606483
# 3        505.74  2.0   NaN  35.0625  1.039680  9.38386 -1.595650  0.772609
# 4        505.75  2.0   NaN  35.0625  1.070930  9.38219 -1.827400  0.938327
# ...         ...  ...   ...      ...       ...      ...       ...       ...
# 145995  2305.66  4.0   NaN  35.6875  2.140840  7.09274 -0.213018  2.107840
# 145996  2305.67  4.0   NaN  35.6875  2.027390  6.56647 -0.135921  2.015190
# 145997  2305.68  4.0   NaN  35.6875  1.978930  6.11268 -0.445092  1.861420
# 145998  2305.69  4.0   NaN  35.6875  1.677590  5.73813 -0.294450  1.707950
# 145999  2305.70  4.0   NaN  35.6875  1.217980  5.32511 -0.340155  1.449760
#
#              8         9         10        11        12        13       14  \
# 0       9.10631 -1.642520 -0.064955  0.033557  0.051343   2.52139 -23.9094
# 1       8.90965 -1.416770  0.063998  0.052043  0.078401   2.12795 -23.8953
# 2       8.89380 -1.236830  0.192540  0.034474  0.070010   1.87388 -24.2730
# 3       8.99907 -1.237530  0.282665  0.053817  0.057465   1.73597 -23.3649
# 4       9.21025 -1.419260  0.335187  0.016476  0.011713   2.25530 -24.4165
# ...         ...       ...       ...       ...       ...       ...      ...
# 145995  7.31908 -0.041456  0.256645 -0.568124  0.005918 -12.27830 -50.9797
# 145996  6.94196 -0.041992  0.221546 -0.501649  0.103945 -12.52640 -51.7445
# 145997  6.39894 -0.027528  0.162119 -0.355711  0.133332 -11.76720 -51.6443
# 145998  5.96165 -0.073210  0.122680 -0.262807  0.188172 -12.41520 -51.3625
# 145999  5.60004 -0.102927  0.060416 -0.171433  0.201760 -12.02680 -51.5058
#
#               15        16        17        18        19
# 0        3.66977  0.636708 -0.766698  0.073248  0.037565
# 1        4.08997  0.636387 -0.766974  0.073379  0.037113
# 2        4.23135  0.635648 -0.767586  0.073587  0.036706
# 3        3.94322  0.635121 -0.768060  0.073553  0.035983
# 4        4.65783  0.633378 -0.769606  0.072906  0.034988
# ...          ...       ...       ...       ...       ...
# 145995  20.50000  0.566790 -0.673692 -0.347012 -0.323220
# 145996  20.64360  0.566736 -0.675315 -0.345593 -0.321443
# 145997  21.35340  0.566580 -0.676581 -0.344391 -0.320344
# 145998  21.34730  0.566308 -0.677672 -0.343209 -0.319786
# 145999  21.35080  0.566066 -0.678469 -0.342133 -0.319678
#
# [146000 rows x 20 columns]

# %%
start_time = 850
end_time = 890

ts = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 10].to_numpy()
ts.shape
# Out:
# (3999,)

# %%
snp = snippets(ts, 600, 2)

# %% [markdown]
# Выполните визулизацию временного ряда и найденных сниппетов с помощью функции `plot_snippets()` из модуля snippets.py.

# %%
plot_snippets(ts, snp)
# Out:
# 600
# <Axes: >

# %% [markdown]
# Оцените точность разметки, полученной при помощи сниппетов, используя исходные данные об активностях в ряде.

# %%
m = len(snp[0][0])
snippets_indices = snp[1]
for i, snippet_start in enumerate(snippets_indices):
    snippet_end = snippet_start + m

labels_pred = np.zeros_like(ts)
snippets_regimes = snp[5]
for regime in snippets_regimes:
    labels_pred[regime[1] : regime[2]] = regime[0]

# %%
labels = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 1].to_numpy()
labels = np.where(labels == 3, 1, labels)
labels = np.where(labels == 17, 0, labels)

# %%
correct_predictions = sum(1 for true, pred in zip(labels, labels_pred) if true == pred)
accuracy = correct_predictions / len(labels)
accuracy
# Out:
# 0.5756439109777445

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов.

# %% [markdown]
# C помощью сниппетов можно кластеризировать временные ряды, хотя в данном случае точность не самая высокая

# %% [markdown]
# ### Задача 2. Разметка многомерного временного ряда
#
# Выполните разметку многомерного временно ряда, используя **показания гироскопа по всем трем осям** из набора данных PAMAP. Используйте тот же временной интервал, что и в задаче 1. Итоговую разметку получите в результате голосования большинством.

# %%
start_time = 850
end_time = 880

ts = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 10:13].to_numpy()
ts.shape
# Out:
# (2999, 3)

# %%
snpList=[]
for i in range(3):
    snpList.append(snippets(ts[:,i], 600, 2))

# %%
plot_snippets(ts[:,0], snpList[0])
# Out:
# 600
# <Axes: >

# %%
plot_snippets(ts[:,1], snpList[1])
# Out:
# 600
# <Axes: >

# %%
plot_snippets(ts[:,2], snpList[2])
# Out:
# 600
# <Axes: >

# %% [markdown]
# Оцените точность разметки многомерного ряда, используя исходные данные об активностях.

# %%
def get_label(labels_3d):
    labels = [0 for _ in range(len(labels_3d))]
    for i in range(len(labels_3d)):
        counter = {}
        for label in labels_3d[i]:
            if label in counter:
                counter[label] += 1
            else:
                counter[label] = 1
        labels[i] = max(counter, key=counter.get)
    return labels

# %%
labels = np.zeros_like(ts)
for k, snp_1d in enumerate(snpList):
    m = len(snp[0][0])
    snippets_indices = snp[1]
    for i, snippet_start in enumerate(snippets_indices):
        snippet_end = snippet_start + m

    snippets_regimes = snp[5]
    for regime in snippets_regimes:
        labels_pred[regime[1] : regime[2]] = regime[0]

# %%
labels_pred = get_label(labels)

labels = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 1].to_numpy()
labels = np.where(labels == 3, 1, labels)
labels = np.where(labels == 17, 0, labels)

# %%
correct_predictions = sum(1 for true, pred in zip(labels, labels_pred) if true == pred)
accuracy = correct_predictions / len(labels)
accuracy
# Out:
# 0.6548849616538847

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов. Сравните полученные разметки многомерного и одномерного рядов.

# %% [markdown]
# Многомерные временные ряды также можно размечать с помощью сниппетов

# %% [markdown]
# ## Задача 3. Подбор оптимального значения _k_

# %% [markdown]
# Разработайте программу, которая выполняет выполняет вычисление меры $change$ для различных значений $k$ с помощью алгоритма SnippetFinder. Проведите эксперименты, используя временной ряд из задания 2 (взяв 1 ≤ _k_ ≤ 9).
#
# $Change_k = \frac{ProfileArea_{k-1}}{ProfileArea_k} - 1$

# %%
df = pd.read_csv(r'datasets/PAMAP/PAMAP.txt', sep=' ', header=None).T

# %%
start_time = 850
end_time = 880

ts = df.loc[start_time < df.iloc[:, 0]].loc[df.iloc[:, 0] < end_time].iloc[:, 10].to_numpy()
ts.shape
# Out:
# (2999,)

# %%
snippets(ts, 500, 2)[4]
# Out:
# array([77923.7904287 , 69580.57835543])

# %%
snippets(ts, 500, 3)[4]
# Out:
# array([77923.7904287 , 69580.57835543, 67522.90985542])

# %%
snippets(ts, 500, 8)[4]
# Out:
# array([77923.7904287 , 69580.57835543, 67522.90985542, 66544.17915677,
#        66301.58427439, 66301.58427439, 66301.58427439, 66301.58427439])

# %%
k = 9
snippets = snippets(ts, 500, k)
prof_area = snippets[4]
prof_area
# Out:
# array([77923.7904287 , 69580.57835543, 67522.90985542, 66544.17915677,
#        66301.58427439, 66301.58427439, 66301.58427439, 66301.58427439,
#        66301.58427439])

# %%
change = []
for i in range(1, 9):
    change.append(prof_area[i-1] / prof_area[i] - 1)

# %% [markdown]
# Выполните визуализацию результатов экспериментов в следующем виде: отображение столбчатых диаграм со значениями $ProfileArea$ и меры $change$ в зависимости от $k$.

# %%
import plotly.express as px

# %%
df = pd.DataFrame([range(1, 10), prof_area]).T
df.columns = ['k', 'ProfileArea']
px.bar(df, x='k', y='ProfileArea', labels={'k':'k', 'ProfileArea':'ProfileArea'})

# %%
df = pd.DataFrame([range(2, 10), change]).T
df.columns = ['k', 'Change']
px.bar(df, x='k', y='Change', labels={'k':'k', 'Change':'Change'})

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов. Какое значение $k$ является наилучшим для используемого временного ряда?

# %% [markdown]
# Наилучшее значение k = 2
